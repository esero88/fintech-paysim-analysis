# %% [markdown]
# # PaySim Fraud Analysis - Data Ingestion
#
# In this notebook, the PaySim dataset is downloaded using Kaggle API and prepared for analysis.

# %% [markdown]
# ## Kaggle Connection
#
# Kaggle API credentials are set to access the dataset.

# %%
import os

os.environ['KAGGLE_USERNAME'] = 'eserkaraceper'
os.environ['KAGGLE_KEY'] = 'KGAT_6d05b87aafed37fa1a42960ae53758ca'

# %% [markdown]
# ## Download Dataset
#
# The PaySim dataset is downloaded from Kaggle.

# %%
# !kaggle datasets download -d ealaxi/paysim1
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/ealaxi/paysim1
# License(s): CC-BY-SA-4.0
# ...
#   0%|          | 0.00/178M [00:00<?, ?B/s]
#   1%|          | 1.00M/178M [00:00<02:38, 1.17MB/s]
#   1%|1         | 2.00M/178M [00:01<01:40, 1.84MB/s]
#   2%|1         | 3.00M/178M [00:01<01:21, 2.25MB/s]
#   2%|2         | 4.00M/178M [00:01<01:11, 2.56MB/s]
#   3%|2         | 5.00M/178M [00:02<01:05, 2.76MB/s]
#   3%|3         | 6.00M/178M [00:02<01:02, 2.88MB/s]
#   4%|3         | 7.00M/178M [00:02<00:54, 3.28MB/s]
#   5%|4         | 8.00M/178M [00:02<00:45, 3.89MB/s]
#   5%|5         | 9.00M/178M [00:03<00:40, 4.35MB/s]
#   6%|5         | 10.0M/178M [00:03<00:34, 5.12MB/s]
#   6%|6         | 11.0M/178M [00:03<00:36, 4.75MB/s]
#   7%|6         | 12.0M/178M [00:03<00:34, 5.08MB/s]
#   7%|7         | 13.0M/178M [00:03<00:31, 5.54MB/s]
#   8%|7         | 14.0M/178M [00:04<00:30, 5.70MB/s]
#   8%|8         | 15.0M/178M [00:04<00:29, 5.74MB/s]
#   9%|9         | 16.0M/178M [00:04<00:26, 6.43MB/s]
# ...

# %% [markdown]
# ## Unzip Data
#
# The downloaded zip file is extracted into the data folder.

# %%
import zipfile

with zipfile.ZipFile("paysim1.zip", 'r') as zip_ref:
    zip_ref.extractall("data")
