# %% [markdown]
# ## Git & GitHub Setup (Project Workflow)
#
# This section explains how the project was pushed to GitHub step by step.
#
# ### 1. Initialize Git

# %% [markdown]
# ### 2. Create .gitignore

# %%
data/
*.csv
*.zip
.ipynb_checkpoints/

# %% [markdown]
# ### 3. Add files

# %%
git add .

# %% [markdown]
# ### 4. Commit changes

# %%
git commit -m "initial project setup"

# %% [markdown]
# ### 5. Connect to GitHub repository

# %%
git remote add origin https://github.com/esero88/fintech-paysim-analysis.git

# %% [markdown]
# ### 6. Pull remote changes (if needed)

# %%
git pull origin main --allow-unrelated-histories

# %% [markdown]
# ### 7. Resolve conflicts (if any)
#
# - Open conflicted file
# - Keep correct content
# - Save file

# %%
git add .
git commit -m "resolve conflict"

# %% [markdown]
# ### 8. Push to GitHub

# %%
git branch -M main
git push -u origin main

# %% [markdown]
# ---
#
# ## Notes
#
# - Large files are excluded using `.gitignore`
# - Dataset is downloaded via Kaggle API
# - GitHub authentication uses Personal Access Token (PAT)
